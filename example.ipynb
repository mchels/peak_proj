# %%
import utils
import matplotlib.pyplot as plt
import numpy.random as rnd

# %%
rnd.seed(1)
data, labels = utils.construct_data_and_labels(4)

for d in data:
    fig, ax = plt.subplots()
    ax.plot(d)
    plt.show()
